# %%
import pandas as pd
import geopandas as gdp
import numpy as np
import json
import csv
import argparse
import sys
import os 
import glob

os.chdir("/Users/alim/Documents/GitHub/Team-4-AI-4-Good-lab/datasets/world-bank-data")

df = pd.read_csv('cons_agg_wave3_visit2.csv')

df.head(3)
# Out:
#   country  wave  visit  ...       nfdfoth        totcons      hhweight
# 0     NGA     3      2  ...   9284.722656  189285.296875  11898.657227
# 1     NGA     3      2  ...  30333.332031  479621.875000  11898.657227
# 2     NGA     3      2  ...  11805.556641  243662.796875  11898.657227
#
# [3 rows x 80 columns]

# %%
for i in df['state']:
    if df['state'][i] == "1":
        df['state'][i] = "ABIA"
df.head(5)
# Out:
#   country  wave  visit  ...       nfdfoth        totcons      hhweight
# 0     NGA     3      2  ...   9284.722656  189285.296875  11898.657227
# 1     NGA     3      2  ...  30333.332031  479621.875000  11898.657227
# 2     NGA     3      2  ...  11805.556641  243662.796875  11898.657227
# 3     NGA     3      2  ...   9604.166992  209184.062500  11898.657227
# 4     NGA     3      2  ...   4619.047852  239829.750000  11898.657227
#
# [5 rows x 80 columns]

# %%
df.head(3)
# Out:
#   country  wave  visit  ...       nfdfoth        totcons      hhweight
# 0     NGA     3      2  ...   9284.722656  189285.296875  11898.657227
# 1     NGA     3      2  ...  30333.332031  479621.875000  11898.657227
# 2     NGA     3      2  ...  11805.556641  243662.796875  11898.657227
#
# [3 rows x 80 columns]
